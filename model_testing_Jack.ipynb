# %% [markdown]
# # Imports and Preprocessing

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy import stats
from sklearn.metrics import mean_squared_error
from math import sqrt
from random import randint
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, Dropout
from keras.callbacks import EarlyStopping
from keras import initializers
from matplotlib import pyplot
from datetime import datetime
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, Normalizer
from sklearn.impute import SimpleImputer
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
# import plotly.offline as py
# import plotly.graph_objs as go
# py.init_notebook_mode(connected=True)
# %matplotlib inline

# %% [markdown]
# Import test data

# %%
data = pd.read_csv('/Users/yuhaoli/code/HowardLiYH/Volatility-prediction/datasets/raw/raw_data.csv')
data
# Out:
#               scrape_time  lastUpdateId  bids_price_01  bids_size_01  \
# 0     2023-03-27 10:30:36   17668615506       27905.28      12.59899
# 1     2023-03-27 10:30:41   17668615812       27905.28      13.05932
# 2     2023-03-27 10:30:45   17668616793       27909.14      10.13004
# 3     2023-03-27 10:30:50   17668617069       27909.14       9.63960
# 4     2023-03-27 10:30:54   17668617292       27909.14       0.22453
# ...                   ...           ...            ...           ...
# 7258  2023-03-27 19:54:46   17675595465       27071.21       3.93922
# 7259  2023-03-27 19:54:51   17675595763       27071.21       1.05540
# 7260  2023-03-27 19:54:56   17675596986       27067.00       0.40343
# 7261  2023-03-27 19:55:00   17675598589       27059.43       1.50309
# 7262  2023-03-27 19:55:05   17675599268       27059.43       3.24565
#
#       bids_price_02  bids_size_02  ask_price_01  ask_size_01  ask_price_02  \
# 0          27904.92       0.01921      27905.29      1.58571      27905.30
# 1          27905.15       0.00208      27905.29      3.29816      27905.30
# 2          27909.03       0.09094      27909.15      5.28372      27909.94
# 3          27909.03       0.09094      27909.15      5.83321      27909.16
# 4          27908.60       0.00559      27909.15      6.31910      27909.16
# ...             ...           ...           ...          ...           ...
# 7258       27071.20       0.00232      27071.22      3.04686      27071.26
# 7259       27071.20       0.00232      27071.22      5.07080      27071.32
# 7260       27066.84       0.38190      27067.01      7.31261      27067.05
# 7261       27058.51       0.09800      27059.44      4.31640      27060.11
# 7262       27059.42       0.00530      27059.44      5.76809      27059.61
#
#       ask_size_02
# 0         1.02708
# 1         0.00252
# 2         0.09800
# 3         0.00401
# 4         0.00401
# ...           ...
# 7258      0.70701
# 7259      0.69941
# 7260      0.30726
# 7261      0.55458
# 7262      0.76618
#
# [7263 rows x 10 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %%
data['WAP'] = (data['bids_price_01']*data['bids_size_01']
               +data['bids_price_02']*data['bids_size_02']
               +data['ask_price_01']*data['ask_size_01']
               +data['ask_price_02']*data['ask_size_02'])/(data['bids_size_01']+
                                         data['bids_size_02']+
                                         data['ask_size_01']+
                                         data['ask_size_02'])

data['spread'] = ((data['ask_price_01']/data['bids_price_01']) - 1)

# %%
def log_price(list_stock_prices):
    return np.log(list_stock_prices)

data.insert(0, 'log_price', log_price(data['WAP']))

data['log_returns'] = data.log_price.diff()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 def log_price(list_stock_prices):
#       2     return np.log(list_stock_prices)
# ----> 4 data.insert(0, 'log_price', log_price(data['WAP']))
#       6 data['log_returns'] = data.log_price.diff()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert log_price, already exists

# %%
def realized_volatility(data):
    list_vol = []
    i = 0
    for i in data.index:
        x = np.std(data.log_returns.iloc[:i])
        i += 1
        list_vol.append(x)
    
    return list_vol
data['realized_volatility'] = realized_volatility(data)
data['volatility_t+1'] = data['realized_volatility'].shift(-1)
data
# Out:
#       log_price          scrape_time  lastUpdateId  bids_price_01  \
# 0     10.236571  2023-03-27 10:30:36   17668615506       27905.28
# 1     10.236571  2023-03-27 10:30:41   17668615812       27905.28
# 2     10.236710  2023-03-27 10:30:45   17668616793       27909.14
# 3     10.236710  2023-03-27 10:30:50   17668617069       27909.14
# 4     10.236710  2023-03-27 10:30:54   17668617292       27909.14
# ...         ...                  ...           ...            ...
# 7258  10.206226  2023-03-27 19:54:46   17675595465       27071.21
# 7259  10.206227  2023-03-27 19:54:51   17675595763       27071.21
# 7260  10.206071  2023-03-27 19:54:56   17675596986       27067.00
# 7261  10.205793  2023-03-27 19:55:00   17675598589       27059.43
# 7262  10.205792  2023-03-27 19:55:05   17675599268       27059.43
#
#       bids_size_01  bids_price_02  bids_size_02  ask_price_01  ask_size_01  \
# 0         12.59899       27904.92       0.01921      27905.29      1.58571
# 1         13.05932       27905.15       0.00208      27905.29      3.29816
# 2         10.13004       27909.03       0.09094      27909.15      5.28372
# 3          9.63960       27909.03       0.09094      27909.15      5.83321
# 4          0.22453       27908.60       0.00559      27909.15      6.31910
# ...            ...            ...           ...           ...          ...
# 7258       3.93922       27071.20       0.00232      27071.22      3.04686
# 7259       1.05540       27071.20       0.00232      27071.22      5.07080
# 7260       0.40343       27066.84       0.38190      27067.01      7.31261
# 7261       1.50309       27058.51       0.09800      27059.44      4.31640
# 7262       3.24565       27059.42       0.00530      27059.44      5.76809
#
#       ask_price_02  ask_size_02           WAP        spread   log_returns  \
# 0         27905.30      1.02708  27905.281936  3.583551e-07           NaN
# 1         27905.30      0.00252  27905.282002  3.583551e-07  2.385111e-09
# 2         27909.94      0.09800  27909.147770  3.583056e-07  1.385222e-04
# 3         27909.16      0.00401  27909.143110  3.583056e-07 -1.669880e-07
# 4         27909.16      0.00401  27909.149194  3.583056e-07  2.180208e-07
# ...            ...          ...           ...           ...           ...
# 7258      27071.26      0.70701  27071.218550  3.693961e-07  1.207422e-07
# 7259      27071.32      0.69941  27071.228691  3.693961e-07  3.745986e-07
# 7260      27067.05      0.30726  27067.003258  3.694536e-07 -1.560979e-04
# 7261      27060.11      0.55458  27059.481007  3.695569e-07 -2.779509e-04
# 7262      27059.61      0.76618  27059.449983  3.695569e-07 -1.146489e-06
#
#       realized_volatility  volatility_t+1
# 0                     NaN             NaN
# 1                     NaN        0.000000
# 2                0.000000        0.000069
# 3                0.000069        0.000065
# 4                0.000065        0.000060
# ...                   ...             ...
# 7258             0.000274        0.000274
# 7259             0.000274        0.000274
# 7260             0.000274        0.000274
# 7261             0.000274        0.000274
# 7262             0.000274             NaN
#
# [7263 rows x 16 columns]

# %%
imputer = SimpleImputer(strategy="constant", fill_value = 0) # Instantiate a SimpleImputer object with your strategy of choice

imputer.fit(data[['volatility_t+1']]) # Call the "fit" method on the object

data['volatility_t+1'] = imputer.transform(data[['volatility_t+1']]) # Call the "transform" method on the object

imputer.statistics_ # The mean is stored in the transformer's memory
# Out:
# array([0.])

# %%
data.drop(['realized_volatility', 'WAP', 'spread', 'log_returns', 'log_price', 'lastUpdateId'], axis = 1, inplace = True)

# %%
data = data.set_index(['scrape_time'])

# %%
data
# Out:
#                      bids_price_01  bids_size_01  bids_price_02  bids_size_02  \
# scrape_time
# 2023-03-27 10:30:36       27905.28      12.59899       27904.92       0.01921
# 2023-03-27 10:30:41       27905.28      13.05932       27905.15       0.00208
# 2023-03-27 10:30:45       27909.14      10.13004       27909.03       0.09094
# 2023-03-27 10:30:50       27909.14       9.63960       27909.03       0.09094
# 2023-03-27 10:30:54       27909.14       0.22453       27908.60       0.00559
# ...                            ...           ...            ...           ...
# 2023-03-27 19:54:46       27071.21       3.93922       27071.20       0.00232
# 2023-03-27 19:54:51       27071.21       1.05540       27071.20       0.00232
# 2023-03-27 19:54:56       27067.00       0.40343       27066.84       0.38190
# 2023-03-27 19:55:00       27059.43       1.50309       27058.51       0.09800
# 2023-03-27 19:55:05       27059.43       3.24565       27059.42       0.00530
#
#                      ask_price_01  ask_size_01  ask_price_02  ask_size_02  \
# scrape_time
# 2023-03-27 10:30:36      27905.29      1.58571      27905.30      1.02708
# 2023-03-27 10:30:41      27905.29      3.29816      27905.30      0.00252
# 2023-03-27 10:30:45      27909.15      5.28372      27909.94      0.09800
# 2023-03-27 10:30:50      27909.15      5.83321      27909.16      0.00401
# 2023-03-27 10:30:54      27909.15      6.31910      27909.16      0.00401
# ...                           ...          ...           ...          ...
# 2023-03-27 19:54:46      27071.22      3.04686      27071.26      0.70701
# 2023-03-27 19:54:51      27071.22      5.07080      27071.32      0.69941
# 2023-03-27 19:54:56      27067.01      7.31261      27067.05      0.30726
# 2023-03-27 19:55:00      27059.44      4.31640      27060.11      0.55458
# 2023-03-27 19:55:05      27059.44      5.76809      27059.61      0.76618
#
#                      volatility_t+1
# scrape_time
# 2023-03-27 10:30:36        0.000000
# 2023-03-27 10:30:41        0.000000
# 2023-03-27 10:30:45        0.000069
# 2023-03-27 10:30:50        0.000065
# 2023-03-27 10:30:54        0.000060
# ...                             ...
# 2023-03-27 19:54:46        0.000274
# 2023-03-27 19:54:51        0.000274
# 2023-03-27 19:54:56        0.000274
# 2023-03-27 19:55:00        0.000274
# 2023-03-27 19:55:05        0.000000
#
# [7263 rows x 9 columns]

# %%
# #sum of all bid quantities
# data['bid depth'] = data[['bids_size_01', 'bids_size_02']].sum(axis=1)
      

# #sum of all bid quantities
# data['ask depth'] = data[['ask_size_01', 'ask_size_02']].sum(axis=1)

# #Order Flow Imbalance (OFI) 
# #relative quantities of bids vs asks
# #full depth (approx 20 levels) OFI
# data['FDOFI'] = (data['bid depth']-data['ask depth'])/(data['bid depth']+data['ask depth'])

# data

# %%
X = data.drop('volatility_t+1', axis=1)
y = np.expand_dims(data['volatility_t+1'].values, 1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = MinMaxScaler().fit(X)
X_scaled = scaler.transform(X)
X_scaled.shape
# Out:
# (7263, 8)

# %% [markdown]
# # Multivariate LSTM

# %%
def convert2matrix(X_arr,Y_arr, look_back=1):
    X, Y =[], []
     #iterating thorough the data with window as look back
    for i in range(len(X_arr)-look_back):
        d=i+look_back 
        # extracting the X as features and target of n days and Y as   target at (n+1)th day
        X.append(np.hstack((X_arr[i:d],Y_arr[i:d])))
        Y.append(Y_arr[d])
        
    return np.array(X), np.array(Y)

# %%
# transformer = Normalizer().fit(X)
# n_X = transformer.transform(X)
# n_X.shape

# %%
X.shape, y.shape
# Out:
# ((7263, 8), (7263, 1))

# %%
X_new, y_new = convert2matrix(X_scaled, y, 10)
X_new.shape, y_new.shape
# Out:
# ((7253, 10, 9), (7253, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, shuffle=False)

# %%
model = Sequential()
model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=(X_new.shape[1], X_new.shape[2])))
model.add(LSTM(128, return_sequences=False))
# model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(1))

# compile and fit the model
model.compile(loss='mse', optimizer=Adam(0.001), metrics=['mape'])

# %%
# pipe = Pipeline([('Imputer', SimpleImputer(strategy = 'mean')),
#             ('scaler', MinMaxScaler()),
#             # 'model', ARIMA(order=(2, 1, 3), trend='t')])
#             'model', model])
history = model.fit(X_train, y_train, epochs=100, batch_size=8, shuffle=True,
                    validation_split=0.2,
                    callbacks = 
                    [EarlyStopping(patience=20, verbose=1, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 581/581 [==============================] - 4s 5ms/step - loss: 4.4426e-05 - mape: 3020.7354 - val_loss: 8.0462e-07 - val_mape: 287.5665
# Epoch 2/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.3362e-06 - mape: 941.2495 - val_loss: 8.4290e-08 - val_mape: 88.1522
# Epoch 3/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.4403e-06 - mape: 761.0180 - val_loss: 6.2026e-08 - val_mape: 58.9761
# Epoch 4/100
# 581/581 [==============================] - 2s 4ms/step - loss: 8.9777e-07 - mape: 595.3029 - val_loss: 1.1788e-08 - val_mape: 27.8051
# Epoch 5/100
# 581/581 [==============================] - 2s 4ms/step - loss: 8.1862e-07 - mape: 570.8195 - val_loss: 5.4821e-07 - val_mape: 240.5552
# Epoch 6/100
# 581/581 [==============================] - 2s 4ms/step - loss: 7.9850e-07 - mape: 563.3571 - val_loss: 4.8926e-07 - val_mape: 227.6059
# Epoch 7/100
# 581/581 [==============================] - 2s 4ms/step - loss: 6.9731e-07 - mape: 517.9936 - val_loss: 3.9245e-07 - val_mape: 204.4377
# Epoch 8/100
# 581/581 [==============================] - 2s 4ms/step - loss: 6.6748e-07 - mape: 517.9849 - val_loss: 1.2968e-06 - val_mape: 372.1238
# Epoch 9/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.5828e-07 - mape: 368.9561 - val_loss: 1.3260e-08 - val_mape: 31.8825
# Epoch 10/100
# 581/581 [==============================] - 2s 4ms/step - loss: 4.5522e-07 - mape: 422.1441 - val_loss: 1.5724e-08 - val_mape: 39.3737
# Epoch 11/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.8314e-07 - mape: 334.9588 - val_loss: 1.5069e-08 - val_mape: 39.4883
# Epoch 12/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.5959e-07 - mape: 365.5493 - val_loss: 3.8954e-07 - val_mape: 204.1332
# Epoch 13/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.8678e-07 - mape: 229.3794 - val_loss: 6.1962e-07 - val_mape: 257.5204
# Epoch 14/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.5750e-07 - mape: 313.7997 - val_loss: 2.1108e-08 - val_mape: 47.4146
# Epoch 15/100
# 581/581 [==============================] - 2s 4ms/step - loss: 4.7809e-08 - mape: 136.8220 - val_loss: 1.7141e-07 - val_mape: 135.4121
# Epoch 16/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.2044e-07 - mape: 209.5017 - val_loss: 1.0747e-07 - val_mape: 107.1925
# Epoch 17/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.3667e-07 - mape: 199.7219 - val_loss: 4.9494e-09 - val_mape: 22.7962
# Epoch 18/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.1893e-08 - mape: 110.2713 - val_loss: 1.8711e-08 - val_mape: 44.6454
# Epoch 19/100
# 581/581 [==============================] - 2s 4ms/step - loss: 4.5321e-08 - mape: 131.3918 - val_loss: 3.7774e-09 - val_mape: 19.9647
# Epoch 20/100
# 581/581 [==============================] - 2s 4ms/step - loss: 6.2668e-08 - mape: 132.3188 - val_loss: 4.2909e-08 - val_mape: 67.4602
# Epoch 21/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.2735e-08 - mape: 91.4154 - val_loss: 1.5610e-08 - val_mape: 40.6904
# Epoch 22/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.7919e-08 - mape: 81.2646 - val_loss: 1.1346e-08 - val_mape: 34.0733
# Epoch 23/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.6992e-08 - mape: 78.4797 - val_loss: 3.1124e-10 - val_mape: 5.2101
# Epoch 24/100
# 581/581 [==============================] - 2s 4ms/step - loss: 7.5171e-09 - mape: 52.8844 - val_loss: 2.9018e-09 - val_mape: 17.1348
# Epoch 25/100
# 581/581 [==============================] - 2s 4ms/step - loss: 6.7386e-09 - mape: 49.0693 - val_loss: 3.0240e-09 - val_mape: 17.6820
# Epoch 26/100
# 581/581 [==============================] - 2s 4ms/step - loss: 6.5816e-09 - mape: 50.3570 - val_loss: 5.1982e-10 - val_mape: 6.7467
# Epoch 27/100
# 581/581 [==============================] - 2s 4ms/step - loss: 5.4003e-09 - mape: 45.7368 - val_loss: 6.8144e-10 - val_mape: 6.1059
# Epoch 28/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.1591e-09 - mape: 35.4183 - val_loss: 1.4160e-08 - val_mape: 38.4038
# Epoch 29/100
# 581/581 [==============================] - 2s 4ms/step - loss: 5.0022e-09 - mape: 40.5324 - val_loss: 6.7934e-09 - val_mape: 26.4842
# Epoch 30/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.3888e-09 - mape: 29.7630 - val_loss: 2.5136e-08 - val_mape: 51.6418
# Epoch 31/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.5764e-09 - mape: 31.4178 - val_loss: 1.2171e-08 - val_mape: 35.7193
# Epoch 32/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.0219e-09 - mape: 34.7136 - val_loss: 1.2383e-09 - val_mape: 10.2274
# Epoch 33/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.9484e-09 - mape: 27.4942 - val_loss: 4.9290e-10 - val_mape: 5.1771
# Epoch 34/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.6745e-09 - mape: 32.3691 - val_loss: 5.7581e-10 - val_mape: 6.5333
# Epoch 35/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.2524e-09 - mape: 28.8761 - val_loss: 1.4650e-10 - val_mape: 3.6256
# Epoch 36/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.3160e-09 - mape: 29.6531 - val_loss: 2.8415e-09 - val_mape: 16.6466
# Epoch 37/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.1422e-09 - mape: 28.6231 - val_loss: 7.6213e-09 - val_mape: 28.1727
# Epoch 38/100
# 581/581 [==============================] - 3s 4ms/step - loss: 2.7179e-09 - mape: 32.3802 - val_loss: 8.0372e-10 - val_mape: 7.2580
# Epoch 39/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.2166e-09 - mape: 29.2236 - val_loss: 4.2163e-10 - val_mape: 6.0696
# Epoch 40/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.5027e-09 - mape: 31.1378 - val_loss: 8.0759e-10 - val_mape: 7.1598
# Epoch 41/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.7924e-09 - mape: 32.8273 - val_loss: 2.4505e-10 - val_mape: 4.6850
# Epoch 42/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.4005e-09 - mape: 29.3400 - val_loss: 6.5521e-10 - val_mape: 7.4841
# Epoch 43/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.3173e-09 - mape: 29.5681 - val_loss: 1.6856e-10 - val_mape: 2.8251
# Epoch 44/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.1575e-09 - mape: 28.2915 - val_loss: 4.3213e-10 - val_mape: 4.2991
# Epoch 45/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.6163e-09 - mape: 32.3104 - val_loss: 5.2345e-08 - val_mape: 74.7077
# Epoch 46/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.6142e-09 - mape: 31.0989 - val_loss: 1.1111e-09 - val_mape: 10.0393
# Epoch 47/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.4680e-09 - mape: 30.3864 - val_loss: 5.8859e-09 - val_mape: 24.6074
# Epoch 48/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.9615e-09 - mape: 27.0829 - val_loss: 1.0542e-08 - val_mape: 33.2588
# Epoch 49/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.4753e-09 - mape: 30.2736 - val_loss: 2.4344e-10 - val_mape: 4.6035
# Epoch 50/100
# 581/581 [==============================] - 2s 4ms/step - loss: 3.3068e-09 - mape: 36.0528 - val_loss: 2.0394e-09 - val_mape: 14.0561
# Epoch 51/100
# 581/581 [==============================] - 2s 4ms/step - loss: 1.9983e-09 - mape: 26.5308 - val_loss: 3.3334e-09 - val_mape: 18.3242
# Epoch 52/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.7647e-09 - mape: 31.0927 - val_loss: 1.1333e-09 - val_mape: 10.0222
# Epoch 53/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.2688e-09 - mape: 29.1431 - val_loss: 2.0105e-08 - val_mape: 46.0452
# Epoch 54/100
# 581/581 [==============================] - 2s 4ms/step - loss: 2.8468e-09 - mape: 32.1615 - val_loss: 2.8659e-09 - val_mape: 17.0670
# Epoch 55/100
# 580/581 [============================>.] - ETA: 0s - loss: 2.2377e-09 - mape: 29.2430Restoring model weights from the end of the best epoch: 35.
# 581/581 [==============================] - 2s 4ms/step - loss: 2.2388e-09 - mape: 29.2569 - val_loss: 2.2640e-08 - val_mape: 49.1192
# Epoch 55: early stopping

# %% [markdown]
# BaseLine

# %%
from sklearn.metrics import mean_absolute_error
pred = model.predict(X_test)
plt.figure(figsize=(20,5),dpi=300)
plt.plot(y_test,label='True Value')
plt.plot(pred,linestyle='--', label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 46/46 [==============================] - 0s 2ms/step

# %%
tb_mae = np.mean(np.abs(y_test - pred))
tb_mae
# Out:
# 2.2529926544590225e-05

# %%
pd.DataFrame(pred).value_counts()
# Out:
# 0.000313    2
# 0.000264    1
# 0.000311    1
# 0.000311    1
# 0.000311    1
#            ..
# 0.000302    1
# 0.000302    1
# 0.000302    1
# 0.000302    1
# 0.000373    1
# Length: 1450, dtype: int64

# %%
pred = model.predict(X_train)
plt.figure(figsize=(20,5),dpi=300)
plt.plot(y_train,label='True Value')
plt.plot(pred,linestyle='--', label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 182/182 [==============================] - 0s 2ms/step

# %%
model.evaluate(X_test, y_test)
# Out:
# 46/46 [==============================] - 0s 2ms/step - loss: 1.7615e-09 - mape: 215.9389
# [1.761501611241556e-09, 215.93887329101562]
