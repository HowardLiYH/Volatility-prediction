# %%
import requests
import pandas as pd
import numpy as np
from time import gmtime, strftime
import time
from google.cloud import bigquery
import os
from csv import writer

# %%
# PROJECT = os.environ.get('GCP_PROJECT')
# DATASET = os.environ.get('BQ_DATASET')
# CRAWL_INTERVAL = int(os.environ.get('CRAWL_INTERVAL'))
# TABLE = 'all'

# table = f"{PROJECT}.{DATASET}.{TABLE}"


def main():
    while True:
        r = requests.get("https://api.binance.com/api/v3/depth",
                     params=dict(symbol="BTCBUSD"))
        if r.status_code == 200:
            result = r.json()
            new_row = process(result)

            with open('new_data.csv', 'a') as f_object:
                writer_object = writer(f_object)
                writer_object.writerow(new_row)

        else:
            print(r.status_code)
        time.sleep(4)


def process(result):
    scrape_time = strftime("%Y-%m-%d %H:%M:%S", gmtime())
    lastUpdateId = result['lastUpdateId']
    bids = np.array(result['bids'][:20])
    asks = np.array(result['asks'][:20])
    combine = np.concatenate((bids,asks)).reshape((80,))

    final = np.concatenate((np.array([scrape_time, lastUpdateId]),combine))
    return final

main()

# %%
r = requests.get("https://api.binance.com/api/v3/depth",
                     params=dict(symbol="BTCBUSD"))

# %%
r = requests.get("https://api.binance.com/api/v3/depth",
                     params=dict(symbol="BTCBUSD"))
if r.status_code == 200:
    result = r.json()
    new_row = process(result)

# %%
def process(result):
    scrape_time = strftime("%Y-%m-%d %H:%M:%S", gmtime())
    lastUpdateId = result['lastUpdateId']
    bids = np.array(result['bids'][:20])
    asks = np.array(result['asks'][:20])
    combine = np.concatenate((bids,asks)).reshape((80,))

    final = np.concatenate((np.array([scrape_time, lastUpdateId]),combine))
    return final

# %%
result
# Out:
# {'lastUpdateId': 17765284296,
#  'bids': [['28048.51000000', '0.30347000'],
#   ['28048.50000000', '0.02313000'],
#   ['28048.32000000', '0.00107000'],
#   ['28048.07000000', '0.00699000'],
#   ['28047.87000000', '0.00504000'],
#   ['28047.83000000', '0.84941000'],
#   ['28047.64000000', '0.78762000'],
#   ['28047.54000000', '0.00040000'],
#   ['28047.44000000', '0.67450000'],
#   ['28047.43000000', '0.00098000'],
#   ['28047.24000000', '0.79503000'],
#   ['28047.13000000', '0.76566000'],
#   ['28047.00000000', '0.00875000'],
#   ['28046.90000000', '0.01580000'],
#   ['28046.88000000', '0.49657000'],
#   ['28046.52000000', '0.00179000'],
#   ['28046.20000000', '0.00640000'],
#   ['28046.15000000', '0.05348000'],
#   ['28045.94000000', '0.02536000'],
#   ['28045.64000000', '0.07000000'],
#   ['28045.63000000', '0.00044000'],
#   ['28045.21000000', '0.02235000'],
#   ['28045.17000000', '0.53257000'],
#   ['28045.16000000', '0.78836000'],
#   ['28045.00000000', '0.04573000'],
#   ['28044.66000000', '0.02500000'],
#   ['28044.58000000', '0.00657000'],
#   ['28044.37000000', '0.00367000'],
#   ['28044.24000000', '0.00996000'],
#   ['28044.08000000', '0.06263000'],
#   ['28043.99000000', '0.02606000'],
#   ['28043.98000000', '0.02539000'],
#   ['28043.44000000', '0.05000000'],
#   ['28043.05000000', '0.00300000'],
#   ['28042.91000000', '0.00046000'],
#   ['28042.83000000', '0.12373000'],
#   ['28042.82000000', '0.10000000'],
#   ['28042.80000000', '0.00224000'],
#   ['28042.76000000', '0.04746000'],
